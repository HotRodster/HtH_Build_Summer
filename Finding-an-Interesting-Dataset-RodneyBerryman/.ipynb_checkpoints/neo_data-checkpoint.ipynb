# %%
import pandas as pd
import math
#List of all astroids
neo_data = pd.read_csv("neo.csv")
neo_data
# Out:
#              id                 name  est_diameter_min  est_diameter_max  \
# 0       2162635  162635 (2000 SS164)          1.198271          2.679415
# 1       2277475    277475 (2005 WK4)          0.265800          0.594347
# 2       2512244   512244 (2015 YE18)          0.722030          1.614507
# 3       3596030          (2012 BV13)          0.096506          0.215794
# 4       3667127          (2014 GE35)          0.255009          0.570217
# ...         ...                  ...               ...               ...
# 90831   3763337           (2016 VX1)          0.026580          0.059435
# 90832   3837603           (2019 AD3)          0.016771          0.037501
# 90833  54017201           (2020 JP3)          0.031956          0.071456
# 90834  54115824           (2021 CN5)          0.007321          0.016370
# 90835  54205447           (2021 TW7)          0.039862          0.089133
#
#        relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0           13569.249224   5.483974e+07         Earth          False
# 1           73588.726663   6.143813e+07         Earth          False
# 2          114258.692129   4.979872e+07         Earth          False
# 3           24764.303138   2.543497e+07         Earth          False
# 4           42737.733765   4.627557e+07         Earth          False
# ...                  ...            ...           ...            ...
# 90831       52078.886692   1.230039e+07         Earth          False
# 90832       46114.605073   5.432121e+07         Earth          False
# 90833        7566.807732   2.840077e+07         Earth          False
# 90834       69199.154484   6.869206e+07         Earth          False
# 90835       27024.455553   5.977213e+07         Earth          False
#
#        absolute_magnitude  hazardous
# 0                   16.73      False
# 1                   20.00       True
# 2                   17.83      False
# 3                   22.20      False
# 4                   20.09       True
# ...                   ...        ...
# 90831               25.00      False
# 90832               26.00      False
# 90833               24.60      False
# 90834               27.80      False
# 90835               24.12      False
#
# [90836 rows x 10 columns]

# %%
#Check for unique values
neo_data.nunique()
# Out:
# id                    27423
# name                  27423
# est_diameter_min       1638
# est_diameter_max       1638
# relative_velocity     90828
# miss_distance         90536
# orbiting_body             1
# sentry_object             1
# absolute_magnitude     1638
# hazardous                 2
# dtype: int64

# %%
#drop sentry_object and orbiting body
neo_data.drop(['sentry_object','orbiting_body'], axis = 1)
# Out:
#              id                 name  est_diameter_min  est_diameter_max  \
# 0       2162635  162635 (2000 SS164)          1.198271          2.679415
# 1       2277475    277475 (2005 WK4)          0.265800          0.594347
# 2       2512244   512244 (2015 YE18)          0.722030          1.614507
# 3       3596030          (2012 BV13)          0.096506          0.215794
# 4       3667127          (2014 GE35)          0.255009          0.570217
# ...         ...                  ...               ...               ...
# 90831   3763337           (2016 VX1)          0.026580          0.059435
# 90832   3837603           (2019 AD3)          0.016771          0.037501
# 90833  54017201           (2020 JP3)          0.031956          0.071456
# 90834  54115824           (2021 CN5)          0.007321          0.016370
# 90835  54205447           (2021 TW7)          0.039862          0.089133
#
#        relative_velocity  miss_distance  absolute_magnitude  hazardous
# 0           13569.249224   5.483974e+07               16.73      False
# 1           73588.726663   6.143813e+07               20.00       True
# 2          114258.692129   4.979872e+07               17.83      False
# 3           24764.303138   2.543497e+07               22.20      False
# 4           42737.733765   4.627557e+07               20.09       True
# ...                  ...            ...                 ...        ...
# 90831       52078.886692   1.230039e+07               25.00      False
# 90832       46114.605073   5.432121e+07               26.00      False
# 90833        7566.807732   2.840077e+07               24.60      False
# 90834       69199.154484   6.869206e+07               27.80      False
# 90835       27024.455553   5.977213e+07               24.12      False
#
# [90836 rows x 8 columns]

# %%
#Find the hazardous neos.
hazardous = neo_data[neo_data['hazardous'] == True]
hazardous
# Out:
#              id                name  est_diameter_min  est_diameter_max  \
# 1       2277475   277475 (2005 WK4)          0.265800          0.594347
# 4       3667127         (2014 GE35)          0.255009          0.570217
# 10     54049873          (2020 OT6)          0.252671          0.564989
# 23      2506491  506491 (2003 UW29)          0.201630          0.450858
# 27      3781344           (2017 RV)          0.110804          0.247765
# ...         ...                 ...               ...               ...
# 90782   3776295           (2017 NH)          0.133216          0.297879
# 90794  54235530          (2022 AY1)          0.104847          0.234444
# 90811   2138404  138404 (2000 HA24)          0.356907          0.798068
# 90812   2377732   377732 (2005 XJ8)          1.034082          2.312278
# 90818   3836727           (2018 XR)          0.508809          1.137732
#
#        relative_velocity  miss_distance orbiting_body  sentry_object  \
# 1           73588.726663   6.143813e+07         Earth          False
# 4           42737.733765   4.627557e+07         Earth          False
# 10          58430.697200   3.833750e+07         Earth          False
# 23         115899.180498   1.510102e+07         Earth          False
# 27          48655.305132   3.279775e+07         Earth          False
# ...                  ...            ...           ...            ...
# 90782       67595.756852   5.681059e+07         Earth          False
# 90794       51149.696785   5.450002e+07         Earth          False
# 90811       33008.617883   7.189835e+07         Earth          False
# 90812       53362.798148   4.756627e+07         Earth          False
# 90818       71465.448580   8.894222e+06         Earth          False
#
#        absolute_magnitude  hazardous
# 1                   20.00       True
# 4                   20.09       True
# 10                  20.11       True
# 23                  20.60       True
# 27                  21.90       True
# ...                   ...        ...
# 90782               21.50       True
# 90794               22.02       True
# 90811               19.36       True
# 90812               17.05       True
# 90818               18.59       True
#
# [8840 rows x 10 columns]

# %%
#What percentage of the recorded neos are hazardous?
hazardous_percentage = round(len(hazardous) / len(neo_data) * 100, 2)
str(hazardous_percentage) + "%"
# Out:
# '9.73%'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#graph nonhazardous vs hazardous neos
sns.countplot(x = 'hazardous', data = neo_data)
plt.show()

# %%
#What is the average miss distance of an NEO?
distance = neo_data['miss_distance']
average_distance = sum(distance)/len(neo_data)
sn_avg_distance = "{:e}".format(average_distance)
sn_avg_distance + " km"
# Out:
# '3.706655e+07 km'

# %%
#What is the average miss distance of a harmful NEO?
distance = hazardous['miss_distance']
average_distance = sum(distance)/len(hazardous)
sn_average_distance_hazardous = "{:e}".format(average_distance)
sn_average_distance_hazardous + " km"
# Out:
# '3.994623e+07 km'

# %%
#What is the average velocity of an NEO?
velocity = neo_data['relative_velocity']
average_velocity = round(sum(velocity)/len(neo_data),6)
str(average_velocity) + " km/h"
# Out:
# '48066.918918 km/h'

# %%
#What is the average velocity of a harmful NEO?
velocity = hazardous['relative_velocity']
average_velocity_hazardous = round(sum(velocity)/len(hazardous),6)
str(average_velocity_hazardous) + " km/h"
# Out:
# '62794.337025 km/h'

# %%
#What is the average maximum estimated diameter of an NEO?
max_diameter = neo_data['est_diameter_max']
average_max_diameter = round(sum(max_diameter)/len(neo_data), 6)
str(average_max_diameter) + " km"
# Out:
# '0.284947 km'

# %%
#What is the average maximum estimated diameter of a harmful NEO?
max_diameter = hazardous['est_diameter_max']
average_max_diameter_hazardous = round(sum(max_diameter)/len(hazardous), 6)
str(average_max_diameter_hazardous) + " km"
# Out:
# '0.657704 km'

# %%
#What is the average minimum estimated diameter of an NEO?
min_diameter = neo_data['est_diameter_min']
average_min_diameter = round(sum(min_diameter)/len(neo_data), 6)
str(average_min_diameter) + " km"
# Out:
# '0.127432 km'

# %%
#What is the average minimum estimated diameter of a harmful NEO?
min_diameter = hazardous['est_diameter_min']
average_min_diameter_hazardous = round(sum(min_diameter)/len(hazardous), 6)
str(average_min_diameter_hazardous) + " km"
# Out:
# '0.294134 km'

# %%
#Summary of the Dataset
neo_data.describe()
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# count  9.083600e+04      90836.000000      90836.000000       90836.000000
# mean   1.438288e+07          0.127432          0.284947       48066.918918
# std    2.087202e+07          0.298511          0.667491       25293.296961
# min    2.000433e+06          0.000609          0.001362         203.346433
# 25%    3.448110e+06          0.019256          0.043057       28619.020645
# 50%    3.748362e+06          0.048368          0.108153       44190.117890
# 75%    3.884023e+06          0.143402          0.320656       62923.604633
# max    5.427591e+07         37.892650         84.730541      236990.128088
#
#        miss_distance  absolute_magnitude
# count   9.083600e+04        90836.000000
# mean    3.706655e+07           23.527103
# std     2.235204e+07            2.894086
# min     6.745533e+03            9.230000
# 25%     1.721082e+07           21.340000
# 50%     3.784658e+07           23.700000
# 75%     5.654900e+07           25.700000
# max     7.479865e+07           33.200000

# %%
#Plot miss_distance differentiate between hazardous and non hazardous
neo_data['x1'] = neo_data.index
sns.scatterplot(x = 'x1' , y = 'miss_distance', hue = 'hazardous', style = 'hazardous', data = neo_data)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='miss_distance'>

# %%
#Plot first 100 for a cleaner graph
sns.scatterplot(x = 'x1' , y = 'miss_distance', hue = 'hazardous', style = 'hazardous', data = neo_data.head(100))
# Out:
# <AxesSubplot:xlabel='x1', ylabel='miss_distance'>

# %%
#Plot random 100 for a more options
sns.scatterplot(x = 'x1' , y = 'miss_distance', hue = 'hazardous', style = 'hazardous', data = neo_data.sample(100))
# Out:
# <AxesSubplot:xlabel='x1', ylabel='miss_distance'>
